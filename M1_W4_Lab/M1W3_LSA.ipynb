# %% [markdown]
# ## Latent Symantic Analysis
# ## Author : Gaurav Khandave
# ## Version : 1.0
# ## Date : 09/15/2016

# %%
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['rec.sport.baseball']
dataset = fetch_20newsgroups(subset='all',shuffle=True, random_state=42, categories=categories)
corpus = dataset.data

# %%
corpus[1]
# Out:
# u'From: schmke@cco.caltech.edu (Kevin Todd Schmidt)\nSubject: NL OPI through first week+\nOrganization: California Institute of Technology, Pasadena\nLines: 184\nNNTP-Posting-Host: sandman.caltech.edu\n\nHere is the OPI (Offensive Production Index) for all NL players with at\nleast 10 at-bats.\n\nIt is early in the season so there are some high numbers.  Barry Bonds\nfinished last season at 0.795.\n\nI welcome comments and suggestions.\n\nKevin\n\nLeague OPI: 0.410\nLeague BA:  0.252\nLeague SLG: 0.375\nLeague OBA: 0.321\n\nRank Player                 OPI     BA    SLG    OBA\n-----------------------------------------------------\n1    Phi,daulton           1.101  0.333  0.875  0.515\n2    Phi,kruk              1.069  0.429  0.821  0.529\n3    Cub,grace             1.007  0.452  0.742  0.514\n4    Cub,may               0.931  0.389  0.889  0.421\n5    Col,boston            0.888  0.545  0.545  0.545\n6    Pit,bell              0.873  0.429  0.714  0.467\n7    Col,galarraga         0.867  0.458  0.708  0.458\n8    StL,pena              0.833  0.400  0.600  0.516\n9    StL,zeile             0.811  0.440  0.560  0.500\n10   Cin,mitchell          0.810  0.429  0.643  0.467\n11   Mon,lansing           0.792  0.419  0.677  0.438\n12   Pit,slaught           0.754  0.474  0.526  0.474\n13   Mon,vanderwal         0.746  0.389  0.556  0.476\n14   NYM,tfernandez        0.709  0.300  0.400  0.500\n15   SnF,martinez          0.697  0.300  0.400  0.500\n16   Hou,bagwell           0.695  0.367  0.567  0.424\n17   Col,hayes             0.686  0.333  0.667  0.364\n18   Col,eyoung            0.682  0.333  0.500  0.407\n19   Mon,alou              0.675  0.371  0.600  0.389\n20   Cin,milligan          0.659  0.333  0.375  0.515\n21   Phi,dykstra           0.646  0.214  0.571  0.405\n22   SnF,bonds             0.624  0.280  0.680  0.333\n22   Flo,conine            0.624  0.393  0.393  0.469\n24   SnD,plantier          0.603  0.286  0.571  0.375\n25   Hou,gonzalez          0.596  0.296  0.667  0.296\n26   Hou,anthony           0.594  0.320  0.480  0.414\n27   Col,cole              0.579  0.318  0.409  0.400\n28   Atl,sanders           0.576  0.357  0.643  0.357\n29   Mon,berry             0.566  0.273  0.273  0.500\n30   Cub,sosa              0.558  0.303  0.545  0.343\n31   StL,jefferies         0.551  0.269  0.692  0.296\n32   Pit,vanslyke          0.549  0.296  0.444  0.387\n33   *Montreal             0.548  0.312  0.490  0.367\n34   Los,butler            0.545  0.296  0.333  0.457\n35   Mon,grissom           0.542  0.333  0.455  0.371\n36   Pit,king              0.536  0.308  0.346  0.438\n37   SnD,gwynn             0.533  0.280  0.400  0.379\n38   Pit,merced            0.532  0.300  0.400  0.391\n39   NYM,murray            0.521  0.308  0.462  0.357\n40   StL,gilkey            0.514  0.312  0.438  0.353\n41   NYM,bonilla           0.507  0.292  0.417  0.370\n42   SnD,walters           0.501  0.300  0.500  0.333\n43   Cub,wilson            0.497  0.323  0.452  0.344\n44   Flo,weiss             0.492  0.261  0.348  0.433\n45   *Philadelphia         0.487  0.243  0.431  0.348\n46   Atl,justice           0.480  0.207  0.448  0.361\n47   *Pittsburgh           0.479  0.292  0.428  0.351\n48   StL,osmith            0.476  0.310  0.448  0.355\n49   Phi,incaviglia        0.473  0.250  0.500  0.308\n50   Pit,young             0.470  0.286  0.500  0.310\n51   *StLouis              0.467  0.275  0.445  0.344\n52   *Colorado             0.459  0.287  0.426  0.327\n53   NYM,hundley           0.458  0.300  0.450  0.333\n54   NYM,orsulak           0.454  0.357  0.429  0.400\n55   SnF,benjamin          0.440  0.200  0.500  0.273\n56   Atl,gant              0.438  0.214  0.464  0.333\n56   *NYMets               0.438  0.261  0.345  0.356\n58   *Houston              0.436  0.260  0.415  0.318\n59   Mon,pitcher           0.434  0.312  0.375  0.353\n60   Phi,morandini         0.433  0.240  0.360  0.321\n61   Hou,cedeno            0.427  0.280  0.440  0.308\n62   C ...

# %% [markdown]
# #### There are lots of punctuations and numbers which we dont require. We will remove those by using following code :

# %%
import re
# Regex for punctuations and numbers.
punctuation = re.compile(r'[-.*=?!+/,":;()\n<>_|0-9]')
# Removing punctuactions and numbers
corpus = [punctuation.sub("", document) for document in corpus]

# %% [markdown]
# #### Now we can see there are lots of email ids in a document of corpus. We need to remove thode unwanted email ids.
# <li> We will first split each word in the document of corpus.
# <li> If there is any '@' symbol present in the word, the word will me removed.
# <li> Using this strategy we will remove unwanted email ids.

# %%
filteredString = ""

# Gets each document with index in a corpus
for i,document in enumerate(corpus,start=0):
    # splits document into words
    wordlist = document.split(" ")
    for index,word in enumerate(wordlist,start=0):
        # Check if word has "@" in word, if there then pop the word
        if '@' in word:
            wordlist.pop(index)
            
    # After removing emailIds, join the wordlist to form an entire string
    filteredString = " ".join(wordlist)
    
    # Replace filteredString with the current document in the corpus
    corpus[i]=filteredString

# %%
corpus[1]
# Out:
# u'From Kevin Todd SchmidtSubject NL OPI through first weekOrganization California Institute of Technology PasadenaLines NNTPPostingHost sandmancaltecheduHere is the OPI Offensive Production Index for all NL players with atleast  atbatsIt is early in the season so there are some high numbers  Barry Bondsfinished last season at I welcome comments and suggestionsKevinLeague OPI League BA  League SLG League OBA Rank Player                 OPI     BA    SLG    OBA    Phidaulton                     Phikruk                        Cubgrace                       Cubmay                         Colboston                      Pitbell                        Colgalarraga                   StLpena                        StLzeile                      Cinmitchell                   Monlansing                    Pitslaught                    Monvanderwal                  NYMtfernandez                 SnFmartinez                   Houbagwell                    Colhayes                      Coleyoung                     Monalou                       Cinmilligan                   Phidykstra                    SnFbonds                      Floconine                     SnDplantier                   Hougonzalez                   Houanthony                    Colcole                       Atlsanders                    Monberry                      Cubsosa                       StLjefferies                  Pitvanslyke                   Montreal                      Losbutler                     Mongrissom                    Pitking                       SnDgwynn                      Pitmerced                     NYMmurray                     StLgilkey                     NYMbonilla                    SnDwalters                    Cubwilson                     Floweiss                      Philadelphia                  Atljustice                    Pittsburgh                    StLosmith                     Phiincaviglia                 Pityoung                      StLouis                       Colorado                      NYMhundley                    NYMorsulak                    SnFbenjamin                   Atlgant                       NYMets                        Houston                       Monpitcher                    Phimorandini                  Houcedeno                     Cinsabo                       SnFmanwaring                  SnFrancisco                   Atlblauser                    SnFthompson                   Houcaminiti                   Flobarberie                   Moncordero                    SnDsheffield                  Loskarros                     SnFwilliams                   SnDmcgriff                    Flodestrade                   Colgirardi                    Atlbream                      Monwood                       Flosantiago                   Phithompson                   SnFclayton                    Lospiazza                     SnDbell                       Loswallach                    Cinlarkin                     Pitgarcia                     Cincinnati                    NYMcoleman                    NYMkent                       StLwhiten                     Cinroberts                    Cubs                          SnFlewis                      Houfinley                     Colclark                      Lospitcher                    SnDiego                       Atllemke                      LosAngeles                    SnFmcgee                      Atlanta                      Cinsanders                   Cinoliver                    SnDgardner                   Losreed                      Phihollins                   Florida                      Losdavis                     Atlpendleton                 SnFclark                     Losstrawberry                Houbiggio                    Phibell                      Flomagadan                   StLpagnozzi                  Pitmartin                    Colbichette                  Houtaubensee                 Monbolick                    Flop ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gauravkhandave/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopset = set(stopwords.words('english'))

# %%
# Add some more stop words to the set
stopset.update(['aa','aaa','ab','bb','hr','[', ']', '{', '}','From','To'])

# %%
stopset
# Out:
# {'From',
#  'To',
#  '[',
#  ']',
#  u'a',
#  'aa',
#  'aaa',
#  'ab',
#  u'about',
#  u'above',
#  u'after',
#  u'again',
#  u'against',
#  u'ain',
#  u'all',
#  u'am',
#  u'an',
#  u'and',
#  u'any',
#  u'are',
#  u'aren',
#  u'as',
#  u'at',
#  'bb',
#  u'be',
#  u'because',
#  u'been',
#  u'before',
#  u'being',
#  u'below',
#  u'between',
#  u'both',
#  u'but',
#  u'by',
#  u'can',
#  u'couldn',
#  u'd',
#  u'did',
#  u'didn',
#  u'do',
#  u'does',
#  u'doesn',
#  u'doing',
#  u'don',
#  u'down',
#  u'during',
#  u'each',
#  u'few',
#  u'for',
#  u'from',
#  u'further',
#  u'had',
#  u'hadn',
#  u'has',
#  u'hasn',
#  u'have',
#  u'haven',
#  u'having',
#  u'he',
#  u'her',
#  u'here',
#  u'hers',
#  u'herself',
#  u'him',
#  u'himself',
#  u'his',
#  u'how',
#  'hr',
#  u'i',
#  u'if',
#  u'in',
#  u'into',
#  u'is',
#  u'isn',
#  u'it',
#  u'its',
#  u'itself',
#  u'just',
#  u'll',
#  u'm',
#  u'ma',
#  u'me',
#  u'mightn',
#  u'more',
#  u'most',
#  u'mustn',
#  u'my',
#  u'myself',
#  u'needn',
#  u'no',
#  u'nor',
#  u'not',
#  u'now',
#  u'o',
#  u'of',
#  u'off',
#  u'on',
#  u'once',
#  u'only',
#  u'or',
#  u'other',
#  u'our',
#  u'ours',
#  u'ourselves',
#  u'out',
#  u'over',
#  u'own',
#  u're',
#  u's',
#  u'same',
#  u'shan',
#  u'she',
#  u'should',
#  u'shouldn',
#  u'so',
#  u'some',
#  u'such',
#  u't',
#  u'than',
#  u'that',
#  u'the',
#  u'their',
#  u'theirs',
#  u'them',
#  u'themselves',
#  u'then',
#  u'there',
#  u'these',
#  u'they',
#  u'this',
#  u'those',
#  u'through',
#  u'to',
#  u'too',
#  u'under',
#  u'until',
#  u'up',
#  u've',
#  u'very',
#  u'was',
#  u'wasn',
#  u'we',
#  u'were',
#  u'weren',
#  u'what',
#  u'when',
#  u'where',
#  u'which',
#  u'while',
#  u'who',
#  u'whom',
#  u'why',
#  u'will',
#  u'with',
#  u'won',
#  u'wouldn',
#  u'y',
#  u'you',
#  u'your',
#  u'yours',
#  u'yourself',
#  u'yourselves',
#  '{',
#  '}'}

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(1,3))

# %%
X = vectorizer.fit_transform(corpus)

# %%
X[0]
# Out:
# <1x176428 sparse matrix of type '<type 'numpy.float64'>'
# 	with 199 stored elements in Compressed Sparse Row format>

# %%
X
# Out:
# <994x176428 sparse matrix of type '<type 'numpy.float64'>'
# 	with 302947 stored elements in Compressed Sparse Row format>

# %%
print X[0]
# Out:
#   (0, 175468)	0.0784681968211
#   (0, 10974)	0.0784681968211
#   (0, 128521)	0.0784681968211
#   (0, 44546)	0.0784681968211
#   (0, 58617)	0.0784681968211
#   (0, 115635)	0.0784681968211
#   (0, 84396)	0.0784681968211
#   (0, 151521)	0.0784681968211
#   (0, 46937)	0.0784681968211
#   (0, 95665)	0.0784681968211
#   (0, 145346)	0.0784681968211
#   (0, 166405)	0.0784681968211
#   (0, 102113)	0.0784681968211
#   (0, 44708)	0.0784681968211
#   (0, 168058)	0.0784681968211
#   (0, 77380)	0.0784681968211
#   (0, 115544)	0.0784681968211
#   (0, 125561)	0.0784681968211
#   (0, 79794)	0.0784681968211
#   (0, 96392)	0.0784681968211
#   (0, 41110)	0.0784681968211
#   (0, 33136)	0.0784681968211
#   (0, 18265)	0.0784681968211
#   (0, 44696)	0.0784681968211
#   (0, 33140)	0.0784681968211
#   :	:
#   (0, 138484)	0.0443419306061
#   (0, 152605)	0.0514228317175
#   (0, 63201)	0.0551760257681
#   (0, 173778)	0.0256169679244
#   (0, 25584)	0.0443419306061
#   (0, 151933)	0.024645272705
#   (0, 15188)	0.0580957722552
#   (0, 65916)	0.0380502147649
#   (0, 48536)	0.0740551731421
#   (0, 171689)	0.0254488741496
#   (0, 125827)	0.0609513070188
#   (0, 104565)	0.117933891051
#   (0, 22978)	0.0633799692047
#   (0, 76581)	0.0665110593339
#   (0, 7888)	0.0180940495573
#   (0, 136775)	0.0648333055973
#   (0, 145944)	0.0648333055973
#   (0, 29948)	0.0455943285731
#   (0, 160459)	0.0423970749843
#   (0, 95473)	0.0648333055973
#   (0, 160506)	0.0222865534233
#   (0, 141619)	0.0400877981517
#   (0, 11543)	0.0340888681636
#   (0, 48542)	0.0740551731421
#   (0, 33047)	0.176900836577

# %%
X.shape
# Out:
# (994, 176428)

# %% [markdown]
# ### Matrix has 994 documents and 176428 'concepts'
# #### We will truncate it to find concecpts in the corpus

# %%
lsa = TruncatedSVD(n_components=14, n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=14, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_
# Out:
# array([[ 0.00056901,  0.00056901,  0.00056901, ...,  0.00047405,
#          0.00047405,  0.00047405],
#        [ 0.03443523,  0.0052594 , -0.02075006, ..., -0.00052214,
#         -0.00052214, -0.00052214],
#        [-0.00972563,  0.02271531, -0.07695336, ...,  0.00036821,
#          0.00036821,  0.00036821],
#        ...,
#        [-0.02288842, -0.0015804 , -0.01100626, ..., -0.00075889,
#         -0.00075889, -0.00075889],
#        [ 0.00033756, -0.02273201, -0.07288953, ..., -0.00033091,
#         -0.00033091, -0.00033091],
#        [-0.00349988,  0.02370239, -0.03820116, ..., -0.00029227,
#         -0.00029227, -0.00029227]])

# %%
terms = vectorizer.get_feature_names()

# %%
terms
# Out:
# [u'aaaaarrrrghearlier',
#  u'aaaaarrrrghearlier thread',
#  u'aaaaarrrrghearlier thread commented',
#  u'aaaand',
#  u'aaaand improve',
#  u'aaaand improve would',
#  u'aaabe',
#  u'aaabe successful',
#  u'aaabe successful majorscurrent',
#  u'aaajavy',
#  u'aaajavy lopez',
#  u'aaajavy lopez proven',
#  u'aaamajors',
#  u'aaamajors duty',
#  u'aaamajors duty main',
#  u'aaamost',
#  u'aaamost catchers',
#  u'aaamost catchers need',
#  u'aaano',
#  u'aaano maybe',
#  u'aaano maybe need',
#  u'aaasee',
#  u'aaasee catchers',
#  u'aaasee catchers need',
#  u'aaboston',
#  u'aaboston red',
#  u'aaboston red sox',
#  u'aactually',
#  u'aactually dave',
#  u'aactually dave stewart',
#  u'aafter',
#  u'aafter striking',
#  u'aafter striking bad',
#  u'aardvark',
#  u'aardvark spicalalocuscomwarren',
#  u'aardvark spicalalocuscomwarren usui',
#  u'aaron',
#  u'aaron alextrebek',
#  u'aaron alextrebek said',
#  u'aaron beardsubject',
#  u'aaron beardsubject torre',
#  u'aaron ernie',
#  u'aaron ernie lombardi',
#  u'aaron frank',
#  u'aaron frank robinson',
#  u'aaron henderson',
#  u'aaron henderson morgan',
#  u'aaron henderson morganbonds',
#  u'aaron home',
#  u'aaron home run',
#  u'aaron homered',
#  u'aaron homered bill',
#  u'aaron isubject',
#  u'aaron isubject wounded',
#  u'aaron klein',
#  u'aaron klein frobinson',
#  u'aaron magical',
#  u'aaron magical braves',
#  u'aaron mays',
#  u'aaron mays frobinson',
#  u'aaron ott',
#  u'aaron ott robinson',
#  u'aaron pitcherdavid',
#  u'aaron pitcherdavid fry',
#  u'aaron pitcherwell',
#  u'aaron pitcherwell jewish',
#  u'aaron robinson',
#  u'aaron robinson ott',
#  u'aaron runs',
#  u'aaron runs everybody',
#  u'aaron stan',
#  u'aaron stan musial',
#  u'aaron wagner',
#  u'aaron wagner speaker',
#  u'aaverage',
#  u'aaverage ppoor',
#  u'aaverage ppoor bvery',
#  u'abackend',
#  u'abackend perfect',
#  u'abackend perfect gamehow',
#  u'abackend perfect gamewell',
#  u'abad',
#  u'abad finish',
#  u'abad finish last',
#  u'abase',
#  u'abase balls',
#  u'abase balls umpire',
#  u'abberation',
#  u'abberation norm',
#  u'abberation norm seems',
#  u'abberation thoughts',
#  u'abberation thoughts thought',
#  u'abborn',
#  u'abborn july',
#  u'abborn july year',
#  u'abbot',
#  u'abbot cy',
#  u'abbot cy young',
#  u'abbot cy youngspare',
#  u'abbot key',
#  u'abbot key perez',
#  u'abbott',
#  u'abbott besides',
#  u'abbott besides domingo',
#  u'abbott big',
#  u'abbott big hit',
#  u'abbott first',
#  u'abbott first start',
#  u'abbott inspirational',
#  u'abbott inspirational person',
#  u'abbott one',
#  u'abbott one truly',
#  u'abbott pitching',
#  u'abbott pitching well',
#  u'abbott provide',
#  u'abbott provide great',
#  u'abbott trade',
#  u'abbott trade think',
#  u'abbott tradebleagh',
#  u'abbott tradebleagh terrific',
#  u'abbottcheersvalentine',
#  u'abbotthowever',
#  u'abbotthowever afraid',
#  u'abbotthowever afraid andres',
#  u'abbotts',
#  u'abbotts much',
#  u'abbotts much give',
#  u'abbrev',
#  u'abbrev woesorganization',
#  u'abbrev woesorganization american',
#  u'abbrev woesorganization brandeis',
#  u'abbrev woesorganization skidmore',
#  u'abbreviation',
#  u'abbreviation clitoris',
#  u'abbreviation clitoris polymorph',
#  u'abbreviation oftheir',
#  u'abbreviation oftheir performance',
#  u'abbreviations',
#  u'abbreviations makeabsolutely',
#  u'abbreviations makeabsolutely sense',
#  u'abdominal',
#  u'abdominal muscle',
#  u'abdominal muscle something',
#  u'abig',
#  u'abig deal',
#  u'abig deal like',
#  u'abig inningalso',
#  u'abig inningalso bonds',
#  u'abig question',
#  u'abig question mark',
#  u'abilities',
#  u'abilities aresimilar',
#  u'abilities aresimilar like',
#  u'abilities dodgers',
#  u'abilities dodgers could',
#  u'ability',
#  u'ability attitude',
#  u'ability attitude sgot',
#  u'ability based',
#  u'ability based data',
#  u'ability bat',
#  u'ability bat effectively',
#  u'ability call',
#  u'ability call game',
#  u'ability cause',
#  u'ability cause offensive',
#  u'ability comes',
#  u'ability comes nowhere',
#  u'ability criticinvariably',
#  u'ability criticinvariably makes',
#  u'ability even',
#  u'ability even nothing',
#  u'ability except',
#  u'ability except fordrawing',
#  u'ability explain',
#  u'ability explain tiny',
#  u'ability field',
#  u'ability field grounders',
#  u'ability figured',
#  u'ability figured wickman',
#  u'ability hit',
#  u'ability hit average',
#  u'ability hit clutch',
#  u'ability hit oh',
#  u'ability hit pitch',
#  u'ability hitwell',
#  u'ability hitwell clutch',
#  u'ability kid',
#  u'ability kid improve',
#  u'ability led',
#  u'ability led stick',
#  u'ability look',
#  u'ability look postseason',
#  u'ability many',
#  u'ability many extra',
#  u'ability muchsmaller',
#  u'ability muchsmaller variance',
#  u'ability nothing',
#  u'ability nothing getting',
#  u'ability obpavg',
#  u'ability obpavg dnot',
#  u'ability picka',
#  u'ability picka player',
#  u'ability players',
#  u'ability players hit',
#  u'ability proposed',
#  u'ability proposed definition',
#  u'ability raise',
#  u'ability raise prices',
#  u'ability rate',
#  u'ability rate players',
#  u'ability sayabove',
#  u'ability sayabove agree',
#  u'ability scoring',
#  u'ability scoring runs',
#  u'ability toactively',
#  u'ability toactively prevent',
#  u'ability toconceive',
#  u'ability toconceive premisevalentine',
#  u'ability tohit',
#  u'ability tohit clutch',
#  u'ability toiperform',
#  u'ability toiperform clutch',
#  u'ability turn',
#  u'ability turn notch',
#  u'ability umpirebut',
#  u'ability umpirebut seen',
#  u'ability walk',
#  u'ability walk infielder',
#  u'ability wanna',
#  u'ability wanna bet',
#  u'ability win',
#  u'ability win nothing',
#  u'ability winwell',
#  u'ability winwell certainly',
#  u'ability would',
#  u'ability would rather',
#  u'ability wouldlove',
#  u'ability wouldlove however',
#  u'abilitythey',
#  u'abilitythey many',
#  u'abilitythey many low',
#  u'abilityto',
#  u'abilityto field',
#  u'abilityto field sorts',
#  u'abilityto pitch',
#  u'abilityto pitch toronto',
#  u'abilityto transcend',
#  u'abilityto transcend homer',
#  u'abilityyou',
#  u'abilityyou plenty',
#  u'abilityyou plenty happy',
#  u'abit',
#  u'abit also',
#  u'abit also perceive',
#  u'able',
#  u'able applied',
#  u'able applied broadly',
#  u'able beat',
#  u'able beat may',
#  u'able believe',
#  u'able believe tell',
#  u'able come',
#  u'able come know',
#  u'able come much',
#  u'able come upwith',
#  u'able develop',
#  u'able develop good',
#  u'able duplicate',
#  u'able duplicate surpass',
#  u'able edit',
#  u'able edit seem',
#  u'able find',
#  u'able find whether',
#  u'able follow',
#  u'able follow start',
#  u'able get',
#  u'able get clark',
#  u'able get hold',
#  u'able get tickets',
#  u'able get till',
#  u'able get two',
#  u'able help',
#  u'able help old',
#  u'able help outthe',
#  u'able helpall',
#  u'able helpall fun',
#  u'able identify',
#  u'able identify players',
#  u'able improve',
#  u'able improve results',
#  u'able keep',
#  u'able keep baseball',
#  u'able keeping',
#  u'able keeping footnear',
#  u'able live',
#  u'able live totheir',
#  u'able make',
#  u'able make reasonable',
#  u'able may',
#  u'able may appropriate',
#  u'able pitch',
#  u'able pitch entire',
#  u'able pool',
#  u'able pool resources',
#  u'able predict',
#  u'able predict future',
#  u'able predict futurei',
#  u'able predict player',
#  u'able prove',
#  u'able prove statistics',
#  u'able pull',
#  u'able pull strings',
#  u'able quite',
#  u'able quite things',
#  u'able reach',
#  u'able reach back',
#  u'able say',
#  u'able say absolutely',
#  u'able say anything',
#  u'able send',
#  u'able send syracuse',
#  u'able sign',
#  u'able sign nothing',
#  u'able step',
#  u'able step immediately',
#  u'able step take',
#  u'able teach',
#  u'able teach relaxationto',
#  u'able toget',
#  u'able toget ok',
#  u'able tosustain',
#  u'able tosustain pace',
#  u'able towin',
#  u'able towin lord',
#  u'able treat',
#  u'able treat folks',
#  u'able walk',
#  u'able walk get',
#  u'able wants',
#  u'able wants todo',
#  u'able win',
#  u'able win might',
#  u'ableto',
#  u'ableto eat',
#  u'ableto eat anything',
#  u'ableto get',
#  u'ableto get great',
#  u'ableto play',
#  u'ableto play well',
#  u'ablow',
#  u'ablow two',
#  u'ablow two games',
#  u'abner',
#  u'abner miller',
#  u'abner miller writesorioles',
#  u'abner millersubject',
#  u'abner millersubject america',
#  u'abner millersubject could',
#  u'abner millersubject jewish',
#  u'abner millersubject john',
#  u'abner millersubject sex',
#  u'abner millersubject ugliest',
#  u'abo',
#  u'abo deion',
#  u'abo deion lofton',
#  u'aboba',
#  u'aboba jet',
#  u'aboba jet propulsion',
#  u'abook',
#  u'abook remember',
#  u'abook remember weekend',
#  u'aborted',
#  u'aborted inning',
#  u'aborted inning start',
#  u'abortion',
#  u'abortion team',
#  u'abortion team still',
#  u'abott',
#  u'abott trade',
#  u'abott trade trade',
#  u'abouta',
#  u'abouta done',
#  u'abouta done deal',
#  u'aboutany',
#  u'aboutany darn',
#  u'aboutany darn thing',
#  u'aboutany part',
#  u'aboutany part us',
#  u'aboutbaseball',
#  u'aboutbaseball average',
#  u'aboutbaseball average mailbox',
#  u'aboutbaseball wwii',
#  u'aboutbaseball wwii told',
#  u'aboutcatchers',
#  u'aboutcatchers idea',
#  u'aboutcatchers idea evaluate',
#  u'aboutgehrig',
#  u'aboutgehrig shortened',
#  u'aboutgehrig shortened capitalized',
#  u'abouther',
#  u'abouther fingernails',
#  u'abouther fingernails care',
#  u'abouthere',
#  u'abouthere comes',
#  u'abouthere comes wild',
#  u'abouthis',
#  u'abouthis batting',
#  u'abouthis batting stance',
#  u'abouthispanic',
#  u'abouthispanic players',
#  u'abouthispanic players including',
#  u'aboutkleskoschuerholz',
#  u'aboutkleskoschuerholz well',
#  u'aboutkleskoschuerholz well still',
#  u'aboutmany',
#  u'aboutmany many',
#  u'aboutmany many times',
#  u'aboutmoneygrubbing',
#  u'aboutmoneygrubbing see',
#  u'aboutmoneygrubbing see anyone',
#  u'aboutmy',
#  u'aboutmy masculinity',
#  u'aboutmy masculinity party',
#  u'aboutpittsburgh',
#  u'aboutpittsburgh depends',
#  u'aboutpittsburgh depends uniforms',
#  u'aboutpittsburgh many',
#  u'aboutpittsburgh many teams',
#  u'aboutpredicting',
#  u'aboutpredicting runs',
#  u'aboutpredicting runs given',
#  u'aboutprospects',
#  u'aboutprospects relationship',
#  u'aboutprospects relationship age',
#  u'aboutsensitive',
#  u'aboutsensitive insecure',
#  u'aboutsensitive insecure toronto',
#  u'aboutthe',
#  u'aboutthe indians',
#  u'aboutthe indians objectively',
#  u'aboutthe pitch',
#  u'aboutthe pitch called',
#  u'aboutthe pitching',
#  u'aboutthe pitching rick',
#  u'aboutthe teams',
#  u'aboutthe teams enthused',
#  u'aboutthis',
#  u'aboutthis guy',
#  u'aboutthis guy russell',
#  u'aboutthose',
#  u'aboutthose players',
#  u'aboutthose players opposed',
#  u'aboveaverage',
#  u'aboveaverage first',
#  u'aboveaverage first baseman',
#  u'aboveaverage players',
#  u'aboveaverage players make',
#  u'aboveaverage year',
#  u'aboveaverage year last',
#  u'abovebelow',
#  u'abovebelow switched',
#  u'abovebelow switched thedifference',
#  u'abovefor',
#  u'abovefor extra',
#  u'abovefor extra minutesgame',
#  u'aboveor',
#  u'aboveor average',
#  u'aboveor average clutch',
#  u'abovereplacement',
#  u'abovereplacement rar',
#  u'abovereplacement rar cf',
#  u'abovethat',
#  u'abovethat solid',
#  u'abovethat solid reason',
#  u'abs',
#  u'abs defined',
#  u'abs defined clutch',
#  u'abs early',
#  u'abs early inhis',
#  u'abs hits',
#  u'abs hits average',
#  u'abs sounds',
#  u'abs sounds pretty',
#  u'abs time',
#  u'abs time theywere',
#  u'abs would',
#  u'abs would geared',
#  u'absearlier',
#  u'absearlier never',
#  u'absearlier never fulltime',
#  u'absence',
#  u'absence approved',
#  u'absence approved ruling',
#  u'absent',
#  u'absent thenet',
#  u'absent thenet figured',
#  u'abslg',
#  u'abslg aboba',
#  u'abslg aboba jet',
#  u'absolute',
#  u'absolute certainity',
#  u'absolute certainity whatthe',
#  u'absolute subjectivity',
#  u'absolute subjectivity refuse',
#  u'absolute superiority',
#  u'absolute superiority united',
#  u'absolutely',
#  u'absolutely bizarrestatements',
#  u'absolutely bizarrestatements value',
#  u'absolutely catching',
#  u'absolutely catching prospects',
#  u'absolutely certain',
#  u'absolutely certain carew',
#  u'absolutely completely',
#  u'absolutely completely dead',
#  u'absolutely correct',
#  u'absolutely correct braves',
#  u'absolutely hammered',
#  u'absolutely hammered crap',
#  u'absolutely last',
#  u'absolutely last chance',
#  u'absolutely necessary',
#  u'absolutely necessary reason',
#  u'absolutely player',
#  u'absolutely player team',
#  u'absolutely positively',
#  u'absolutely positively quite',
#  u'absolutely redefined',
#  u'absolutely redefined theposition',
#  u'absolutely refusing',
#  u'absolutely refusing let',
#  u'absolutely sandwichedin',
#  u'absolutely sandwichedin clark',
#  u'absolutely top',
#  u'absolutely top peak',
#  u'absolutely top peaki',
#  u'absolutely vanished',
#  u'absolutely vanished conservatively',
#  u'absolutelyhave',
#  u'absolutelyhave hit',
#  u'absolutelyhave hit clutch',
#  u'absolutelynothing',
#  u'absolutelynothing sport',
#  u'absolutelynothing sport baseball',
#  u'absoluteprimodick',
#  u'absoluteprimodick eddie',
#  u'absoluteprimodick eddie murray',
#  u'abstract',
#  u'abstract ballplayers',
#  u'abstract ballplayers biography',
#  u'abstract books',
#  u'abstract books help',
#  u'abstract covered',
#  u'abstract covered every',
#  u'abstract curiouscould',
#  u'abstract curiouscould someone',
#  u'abstract impressive',
#  u'abstract impressive thing',
#  u'abstract let',
#  u'abstract let forget',
#  u'abstract million',
#  u'abstract million guys',
#  u'abstractdistribution',
#  u'abstractdistribution naorganization',
#  u'abstractdistribution naorganization rutgers',
#  u'abstractdistribution naorganization state',
#  u'abstractorganization',
#  u'abstractorganization school',
#  u'abstractorganization school mpce',
#  u'absurdity',
#  u'absurdity apparent',
#  u'absurdity apparent gee',
#  u'absurdity apparentgarvey',
#  u'absurdity apparentgarvey sucked',
#  u'abuse',
#  u'abuse criticismfrom',
#  u'abuse criticismfrom follow',
#  u'abused',
#  u'abused jim',
#  u'abused jim bunning',
#  u'abutler',
#  u'abutler bdeer',
#  u'abutler bdeer vbonds',
#  u'abysmal',
#  u'abysmal hitting',
#  u'abysmal hitting atlanta',
#  u'abysuccessful',
#  u'abysuccessful advertising',
#  u'abysuccessful advertising campaigns',
#  u'acaddrakeedu',
#  u'acaddrakeedu writes',
#  u'acaddrakeedu writes article',
#  u'acaddrakeedu writes clear',
#  u'acaddrakeedu writesdoes',
#  u'acaddrakeedu writesdoes anyone',
#  u'acaddrakeedu writesi',
#  u'acaddrakeedu writesi remember',
#  u'acaddrakeedu writesor',
#  u'acaddrakeedu writesor second',
#  u'acaddrakeeduorganization',
#  u'acaddrakeeduorganization drake',
#  u'acaddrakeeduorganization drake university',
#  u'academic',
#  u'academic computer',
#  u'academic computer centerfrom',
#  u'academic computing',
#  u'academic computing johns',
#  u'academic user',
#  u'academic user services',
#  u'academic user servicesnntppostinghost',
#  u'accelerator',
#  u'accelerator centerfrom',
#  u'accelerator centerfrom thomas',
#  u'accept',
#  u'accept coaching',
#  u'accept coaching abouthis',
#  u'accept data',
#  u'accept data indication',
#  u'accept full',
#  u'accept full responsibility',
#  u'accept greater',
#  u'accept greater risksany',
#  u'accept part',
#  u'accept part blame',
#  u'accept reasoning',
#  u'accept reasoning findthe',
#  u'accept themthe',
#  u'accept themthe first',
#  u'accept words',
#  u'accept words proves',
#  u'accept workas',
#  u'accept workas happens',
#  u'accept worki',
#  u'accept worki believe',
#  u'acceptably',
#  u'acceptably majors',
#  u'acceptably majors atlanta',
#  u'acceptance',
#  u'acceptance speech',
#  u'acceptance speech voters',
#  u'accepted',
#  u'accepted ernie',
#  u'accepted ernie banks',
#  u'access',
#  u'access internet',
#  u'access internet unix',
#  u'access local',
#  u'access local news',
#  u'access machines',
#  u'access machines close',
#  u'access online',
#  u'access online communications',
#  u'access postingsalbeit',
#  u'access postingsalbeit edited',
#  u'access really',
#  u'access really important',
#  u'access stats',
#  u'access stats priceproject',
#  u'access tothe',
#  u'access tothe point',
#  u'access unix',
#  u'access unix brookline',
#  u'access unix worcester',
#  u'accessdigexnetdoes',
#  u'accessdigexnetdoes anyone',
#  u'accessdigexnetdoes anyone scoop',
#  u'accessed',
#  u'accessed newsgroupsomeone',
#  u'accessed newsgroupsomeone challenge',
#  u'accessto',
#  u'accessto postings',
#  u'accessto postings albeit',
#  u'accessto postings alibet',
#  u'accident',
#  u'accident first',
#  u'accident first two',
#  u'accident got',
#  u'accident got really',
#  u'accidentgo',
#  u'accidentjim',
#  u'accidentjim palmer',
#  u'accidentjim palmer jewish',
#  u'acclimate',
#  u'acclimate highlypromising',
#  u'acclimate highlypromising potential',
#  u'acclimated',
#  u'acclimated dodgers',
#  u'acclimated dodgers team',
#  u'acclimated prime',
#  u'acclimated prime get',
#  u'accommodate',
#  u'accommodate mets',
#  u'accommodate mets jets',
#  u'accomplished',
#  u'accomplished barely',
#  u'accomplished barely getting',
#  u'accomplished good',
#  u'accomplished good world',
#  u'accomplishment',
#  u'accomplishment simmon',
#  u'accomplishment simmon tenure',
#  u'accomplishment simmons',
#  u'accomplishment simmons tenure',
#  u'accomplishments',
#  u'accomplishments nohitters',
#  u'accomplishments nohitters strikeouts',
#  u'accomplishments simmons',
#  u'accomplishments simmons tenure',
#  u'accordance',
#  u'accordance instructions',
#  u'accordance instructions concerning',
#  u'according',
#  u'according bill',
#  u'according bill james',
#  u'according da',
#  u'according da information',
#  u'according elias',
#  u'according elias simplemeasure',
#  u'according gammonsadvanced',
#  u'according gammonsadvanced scouts',
#  u'according goons',
#  u'according goons incooperstown',
#  u'according latestbaseball',
#  u'according latestbaseball weekly',
#  u'according reputation',
#  u'according reputation one',
#  u'according rest',
#  u'according rest sdcn',
#  u'according stanky',
#  u'according stanky himselfis',
#  u'according tonineteenth',
#  u'according tonineteenth century',
#  u'according usa',
#  u'according usa today',
#  u'according whetherthey',
#  u'according whetherthey power',
#  u'accordion',
#  u'accordion go',
#  u'accordion go jail',
#  u'account',
#  u'account atthe',
#  u'account atthe start',
#  u'account hofstadter',
#  u'account hofstadter law',
#  u'account mark',
#  u'account mark horan',
#  u'account number',
#  u'account number must',
#  u'account owned',
#  u'account owned shadowy',
#  u'account russ',
#  u'account russ anderson',
#  u'account seem',
#  u'account seem recall',
#  u'account terms',
#  u'account terms factorsintrinsic',
#  u'account theremaining',
#  u'account theremaining percentgreg',
#  u'account violapitched',
#  u'account violapitched half',
#  u'account wrigley',
#  u'account wrigley difference',
#  u'accountplease',
#  u'accountplease reply',
#  u'accountplease reply ibm',
#  u'accountsame',
#  u'accountsame could',
#  u'accountsame could said',
#  u'accredited',
#  u'accredited umpire',
#  u'accredited umpire course',
#  u'accrued',
#  u'accrued good',
#  u'accrued good rating',
#  u'accuracy',
#  u'accuracy account',
#  u'accuracy account seem',
#  u'accuracy coin',
#  u'accuracy coin biased',
#  u'accuracy common',
#  u'accuracy common backgroundof',
#  u'accuracy jeanne',
#  u'accuracy jeanne dixonhave',
#  u'accuracy jeanne dixonon',
#  u'accuracy jeanne dixonthe',
#  u'accurate',
#  u'accurate big',
#  u'accurate big bang',
#  u'accurate descriptionof',
#  u'accurate descriptionof essentially',
#  u'accurate least',
#  u'accurate least asfar',
#  u'accurate measly',
#  u'accurate measly salary',
#  u'accurate predictor',
#  u'accurate predictor future',
#  u'accurate runs',
#  u'accurate runs created',
#  u'accurate salary',
#  u'accurate salary year',
#  u'accurate say',
#  u'accurate say gant',
#  u'accurate team',
#  u'accurate team level',
#  u'accurate think',
#  u'accurate think muchchop',
#  u'accurate unnamed',
#  u'accurate unnamed mediot',
#  u'accurately',
#  u'accurately looking',
#  u'accurately looking many',
#  u'accusation',
#  u'accusation made',
#  u'accusation made puckett',
#  u'accusationagainst',
#  u'accusationagainst clark',
#  u'accusationagainst clark taking',
#  u'accusations',
#  u'accusations canseco',
#  u'accusations canseco bad',
#  u'accusations glenn',
#  u'accusations glenn davis',
#  u'accusations interestingthat',
#  u'accusations interestingthat selected',
#  u'accuse',
#  u'accuse canseco',
#  u'accuse canseco lazy',
#  u'accuse completely',
#  u'accuse completely cooking',
#  u'accuse post',
#  u'accuse post notmake',
#  u'accuse sherri',
#  u'accuse sherri mouthing',
#  u'accused',
#  u'accused instigator',
#  u'accused instigator enjoys',
#  u'accused instigatorthat',
#  u'accused instigatorthat enjoys',
#  u'accused man',
#  u'accused man interference',
#  u'accused ofselfishness',
#  u'accused ofselfishness ever',
#  u'accused poorwork',
#  u'accused poorwork habits',
#  u'accused time',
#  u'accused time caring',
#  u'accustomed',
#  u'accustomed tothe',
#  u'accustomed tothe miami',
#  u'acdalca',
#  u'acdalca writes',
#  u'acdalca writes well',
#  u'ace',
#  u'ace closer',
#  u'ace closer henneman',
#  u'ace randy',
#  u'ace randy johnson',
#  u'acedennis',
#  u'acedennis bennett',
#  u'acedennis bennett th',
#  u'acehe',
#  u'acehe higher',
#  u'acehe higher ranked',
#  u'aceobprediction',
#  u'aceobprediction alomar',
#  u'aceobprediction alomar back',
#  u'achance',
#  u'achance think',
#  u'achance think team',
#  u'achance watch',
#  u'achance watch play',
#  u'achatesmiteduthe',
#  u'achatesmiteduthe red',
#  u'achatesmiteduthe red sox',
#  u'achieved',
#  u'achieved absolute',
#  u'achieved absolute superiority',
#  u'achieved either',
#  u'achieved either mil',
#  u'achievements',
#  u'achievements smiley',
#  u'achievements smiley trade',
#  u'ack',
#  u'ack man',
#  u'ack man apparently',
#  u'ack man still',
#  u'acker',
#  u'acker back',
#  u'acker back anyway',
#  u'acker butkeywords',
#  u'acker butkeywords acker',
#  u'acker cory',
#  u'acker cory snider',
#  u'acker get',
#  u'acker get ring',
#  u'acker goneneither',
#  u'acker goneneither charlie',
#  u'acker got',
#  u'acker got ring',
#  u'acker jim',
#  u'acker jim break',
#  u'acker orioles',
#  u'acker orioles doppleackersnntppostinghost',
#  u'acker slider',
#  u'acker slider kirsch',
#  u'ackercook',
#  u'ackercook pitchalike',
#  u'ackercook pitchalike contest',
#  u'ackers',
#  u'ackers kidnapped',
#  u'ackers kidnapped real',
#  u'ackman',
#  u'ackman nine',
#  u'ackman nine relatives',
#  u'acknowledge',
#  u'acknowledge observationwas',
#  u'acknowledge observationwas plain',
#  u'ackpeople',
#  u'ackpeople cankeep',
#  u'ackpeople cankeep jack',
#  u'ackpeople spotted',
#  u'ackpeople spotted onmany',
#  u'ackpeople spring',
#  u'ackpeople spring training',
#  u'aclubhouse',
#  u'aclubhouse fight',
#  u'aclubhouse fight tworun',
#  u'acolt',
#  u'acolt rd',
#  u'acolt rd starter',
#  u'acomparision',
#  u'acomparision many',
#  u'acomparision many balls',
#  u'acompetent',
#  u'acompetent one',
#  u'acompetent one afford',
#  u'aconflict',
#  u'aconflict penalized',
#  u'aconflict penalized showing',
#  u'aconsensus',
#  u'aconsensus defensive',
#  u'aconsensus defensive prowess',
#  u'acorrection',
#  u'acorrection errorthat',
#  u'acorrection errorthat last',
#  u'acorrection erroryour',
#  u'acorrection erroryour reply',
#  u'acost',
#  u'acost million',
#  u'acost million lot',
#  u'acquire',
#  u'acquire jay',
#  u'acquire jay bell',
#  u'acquired',
#  u'acquired replacementparts',
#  u'acquired replacementparts means',
#  u'acquireslonnie',
#  u'acquireslonnie defense',
#  u'acquireslonnie defense baserunning',
#  u'acquiring',
#  u'acquiring mark',
#  u'acquiring mark whiten',
#  u'acquisition',
#  u'acquisition anyway',
#  u'acquisition anyway houston',
#  u'acquisition decent',
#  u'acquisition decent offense',
#  u'acquisitions',
#  u'acquisitions lind',
#  u'acquisitions lind mcreynolds',
#  u'acquisitions players',
#  u'acquisitions players thatwere',
#  u'acriteria',
#  u'acriteria finein',
#  u'acriteria finein cases',
#  u'across',
#  u'across bag',
#  u'across bag improperly',
#  u'across body',
#  u'across body generates',
#  u'across breadth',
#  u'across breadth major',
#  u'across call',
#  u'across call high',
#  u'across diamond',
#  u'across diamond last',
#  u'across file',
#  u'across file last',
#  u'across multipleorgans',
#  u'across multipleorgans way',
#  u'across nation',
#  u'across nation consider',
#  u'across nation right',
#  u'across nationthis',
#  u'across nationthis precisely',
#  u'across street',
#  u'across street dead',
#  u'across street second',
#  u'across thechest',
#  ...]

# %%
terms = vectorizer.get_feature_names()
for i, comp in enumerate(lsa.components_): 
    termsInComp = zip (terms,comp)
    sortedTerms =  sorted(termsInComp, key=lambda x: x[1], reverse=True) [:14]
    print "Concept %d:" % i
    for term in sortedTerms:
        print term[0]
    print " "
# Out:
# Concept 0:
# year
# team
# would
# game
# article
# games
# last
# good
# lost
# baseball
# one
# think
# players
# like
#
# Concept 1:
# jewish
# come
# vb
# lowenstein
# jewish baseball
# john lowenstein
# anyone
# stankowitz
# able come
# sandy koufax
# players past
# anyone come
# except sandy
# except sandy koufax
#
# Concept 2:
# year
# well
# would
# team
# aaaand improve
# good
# win
# clutch
# baseball
# players
# writesin
# player
# see
# sabo
#
# Concept 3:
# runs
# run
# year
# good
# baseball
# would
# morris
# got
# extra
# aaaand improve
# play
# hits stolen
# dcon
# best
#
# Concept 4:
# team
# think
# win
# play
# go
# wins
# going
# roger
# hit
# know
# last year
# games
# yankees
# aaabe
#
# Concept 5:
# lost
# good
# morris
# let
# sox
# hall
# say
# back
# run
# well
# take
# players
# aaaand
# pitcher
#
# Concept 6:
# one
# even
# year
# team
# season
# university
# back
# good
# last year
# anyone
# cubs
# know
# aaaaarrrrghearlier thread commented
# pitching
#
# Concept 7:
# aaaand improve
# first
# last
# games
# see
# season
# hitter
# well
# hit
# really
# article
# league
# day
# win
#
# Concept 8:
# team
# really
# games
# still
# last
# game
# even
# make
# win
# better
# aaaand improve
# article
# least
# runs
#
# Concept 9:
# players
# hit
# pitching
# baseball
# best
# much
# one
# start
# ball
# games
# maybe
# last
# season
# good
#
# Concept 10:
# like
# lost
# home
# aaabe successful
# lot
# writes
# go
# hirschbeck
# best
# probably
# last
# pitcher
# one
# done
#
# Concept 11:
# braves
# many
# one
# much
# better
# aaaand
# runs
# mets
# time
# really
# win
# aaaand improve would
# though
# also
#
# Concept 12:
# better
# aaabe successful
# good
# article
# first
# player
# know
# come
# series
# guys
# long
# get
# pitcher
# west
#
# Concept 13:
# year
# go
# could
# new
# hitting
# aaaand improve
# team
# one
# writes
# best
# ball
# player
# every
# something

# %% [markdown]
# ### After LSA of baseball news group, Following concepts are found :
# <li>Last year baseball team lost games
# <li>Jewish come to see jewish baseball
# <li>Second teams hit much and win games
# <li>People could also win pitching first
